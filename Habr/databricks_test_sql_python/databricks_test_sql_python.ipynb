# %% [markdown]
# ### Файлы

# %%
# Список загруженных файлов
dbutils.fs.ls("dbfs:/FileStore/tables/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: [FileInfo(path=&#39;dbfs:/FileStore/tables/geo_json.json&#39;, name=&#39;geo_json.json&#39;, size=936),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/sales_fact.csv&#39;, name=&#39;sales_fact.csv&#39;, size=1944),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/sales_plan.xlsx&#39;, name=&#39;sales_plan.xlsx&#39;, size=8884)]</div>

# %%
# Удаление файлов
# dbutils.fs.rm("dbfs:/FileStore/tables/sales_plan.xlsx")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### База данных

# %%
# %sql
-- Создание новой базы данных.
drop database if exists sales;
create database sales;
use sales;
show databases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>sales</td></tr></tbody></table></div>

# %%
# %sql
-- Создание и заполнение таблицы значениями из файла csv
drop table if exists sales_fact;
create table sales_fact using csv options (path "dbfs:/FileStore/tables/sales_fact.csv", header "true", sep ";")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Группировка фактических продаж (разрез город)
select sf.city, sum(sf.amount) as total_amount_fact from sales_fact as sf group by sf.city
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>total_amount_fact</th></tr></thead><tbody><tr><td>3_7</td><td>98.0</td></tr><tr><td>1_3</td><td>198.0</td></tr><tr><td>2_4</td><td>66.0</td></tr><tr><td>2_5</td><td>58.0</td></tr><tr><td>3_8</td><td>155.0</td></tr><tr><td>4_11</td><td>136.0</td></tr><tr><td>4_12</td><td>89.0</td></tr><tr><td>1_1</td><td>187.0</td></tr><tr><td>1_2</td><td>115.0</td></tr><tr><td>2_6</td><td>229.0</td></tr><tr><td>4_10</td><td>115.0</td></tr><tr><td>3_9</td><td>56.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Датафреймы

# %%
# %python
# Запись результата запроса в датафрейм
df_sales_fact = spark.sql("select sf.city, sum(sf.amount) as total_amount_fact from sales_fact as sf group by sf.city")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
# Излечение данных из файла формата json
df_geo = spark.read.json("dbfs:/FileStore/tables/geo_json.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
# Излечение данных из файла формата xlsx
df_sales_plan = spark.read.format("com.crealytics.spark.excel") \
                          .option("header", "true") \
                          .option("inferSchema", "true") \
                          .load("dbfs:/FileStore/tables/sales_plan.xlsx") \
                          .withColumnRenamed("amount","total_amount_plan")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
# Объединение двух датафреймов
df_sales_fact_ = df_sales_fact.join(df_geo, df_sales_fact.city == df_geo.code_city) 
display(df_sales_fact_.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>total_amount_fact</th><th>code_city</th><th>code_region</th><th>name_city</th><th>name_region</th></tr></thead><tbody><tr><td>3_7</td><td>98.0</td><td>3_7</td><td>3</td><td>city7</td><td>south</td></tr><tr><td>1_3</td><td>198.0</td><td>1_3</td><td>1</td><td>city3</td><td>north</td></tr><tr><td>2_4</td><td>66.0</td><td>2_4</td><td>2</td><td>city4</td><td>east</td></tr><tr><td>2_5</td><td>58.0</td><td>2_5</td><td>2</td><td>city5</td><td>east</td></tr><tr><td>3_8</td><td>155.0</td><td>3_8</td><td>3</td><td>city8</td><td>south</td></tr></tbody></table></div>

# %%
# %python
# Отбор столбцов
df_sales_fact_final = df_sales_fact_.select("name_city","name_region","total_amount_fact") \
                                    .orderBy("name_region","total_amount_fact") \
                                    .withColumnRenamed("name_city","city")
display(df_sales_fact_final.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>name_region</th><th>total_amount_fact</th></tr></thead><tbody><tr><td>city5</td><td>east</td><td>58.0</td></tr><tr><td>city4</td><td>east</td><td>66.0</td></tr><tr><td>city6</td><td>east</td><td>229.0</td></tr><tr><td>city2</td><td>north</td><td>115.0</td></tr><tr><td>city1</td><td>north</td><td>187.0</td></tr></tbody></table></div>

# %%
# %python
# Применение группировки к датафрейму
from pyspark.sql import functions as F
df_sales_fact_group = df_sales_fact_final.groupBy("name_region").agg(F.sum("total_amount_fact").alias("total_amount_fact"))
display(df_sales_fact_group)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name_region</th><th>total_amount_fact</th></tr></thead><tbody><tr><td>west</td><td>340.0</td></tr><tr><td>east</td><td>353.0</td></tr><tr><td>north</td><td>500.0</td></tr><tr><td>south</td><td>309.0</td></tr></tbody></table></div>

# %%
# %python
# Создание вычисляемого столбца
df_sales = df_sales_plan.join(df_sales_fact_group, df_sales_plan.region == df_sales_fact_group.name_region)
df_sales = df_sales.withColumn("delta", F.round((df_sales.total_amount_fact - df_sales.total_amount_plan)/df_sales.total_amount_plan,2))
df_sales = df_sales.withColumn("value", F.when(df_sales.delta>0,"+").when((df_sales.delta>-0.5)&(df_sales.delta<=0),"-").otherwise("--")) \
                   .drop("name_region")                   
display(df_sales)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_amount_plan</th><th>total_amount_fact</th><th>delta</th><th>value</th></tr></thead><tbody><tr><td>east</td><td>600.0</td><td>353.0</td><td>-0.41</td><td>-</td></tr><tr><td>north</td><td>700.0</td><td>500.0</td><td>-0.29</td><td>-</td></tr><tr><td>south</td><td>450.0</td><td>309.0</td><td>-0.31</td><td>-</td></tr><tr><td>west</td><td>500.0</td><td>340.0</td><td>-0.32</td><td>-</td></tr></tbody></table></div>

# %% [markdown]
# ### Графики и диаграммы

# %%
# %python
# Построение графика
display(df_sales_fact_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>name_region</th><th>total_amount_fact</th></tr></thead><tbody><tr><td>city5</td><td>east</td><td>58.0</td></tr><tr><td>city4</td><td>east</td><td>66.0</td></tr><tr><td>city6</td><td>east</td><td>229.0</td></tr><tr><td>city2</td><td>north</td><td>115.0</td></tr><tr><td>city1</td><td>north</td><td>187.0</td></tr><tr><td>city3</td><td>north</td><td>198.0</td></tr><tr><td>city9</td><td>south</td><td>56.0</td></tr><tr><td>city7</td><td>south</td><td>98.0</td></tr><tr><td>city8</td><td>south</td><td>155.0</td></tr><tr><td>city12</td><td>west</td><td>89.0</td></tr><tr><td>city10</td><td>west</td><td>115.0</td></tr><tr><td>city11</td><td>west</td><td>136.0</td></tr></tbody></table></div>
